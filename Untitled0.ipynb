# %% [markdown]
# <a href="https://colab.research.google.com/github/HyBeek/air-quality-analytics-and-forecasting/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Option 1: Open a GitHub notebook directly
#
# You can open a notebook directly from GitHub by going to `File` > `Open notebook` > `GitHub` and pasting the URL of the notebook. Alternatively, you can use the Colab GitHub URL: `https://colab.research.google.com/github/` followed by the GitHub repository path and filename.
#
# For example, if your notebook is at `https://github.com/your-username/your-repo/blob/main/your-notebook.ipynb`, you can open it directly by going to `https://colab.research.google.com/github/your-username/your-repo/blob/main/your-notebook.ipynb`.

# %% [markdown]
# ### Option 2: Clone a GitHub repository
#
# You can clone a GitHub repository directly into your Colab environment using `!git clone`. This is useful if you have multiple files or want to work with a complete project.
#
# First, you'll need to mount your Google Drive to store the cloned repository (optional, but recommended if you want persistence beyond the session):

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Then, navigate to the desired directory (e.g., in your Google Drive) and clone the repository. Replace `your-username/your-repo.git` with the actual repository URL:

# %%
# Change to your desired directory (e.g., in Google Drive)
# %cd /content/drive/My Drive/Colab Notebooks

# Clone the repository
# !git clone https://github.com/your-username/your-repo.git

# List the contents to verify
# %ls your-repo

# %% [markdown]
# ### Option 3: Save a Colab notebook to GitHub
#
# You can save your current Colab notebook directly to GitHub by going to `File` > `Save a copy in GitHub`. You will be prompted to authenticate with GitHub and choose the repository and filename.
